# %% [markdown]
# ## 初始化我们需要的工具

# %%
import requests
from requests.exceptions import HTTPError

# %% [markdown]
# ### 获取首页数据

# %%
def get_data(url):

    response = requests.get(url)
    if response.status_code == requests.codes.ok:  # 检测状态码
        return response.text  # 返回响应的文本信息
    else:
        response.raise_for_status()  # 4xx 5xx 时,引出错误 代替 raise requests.exception.HTTPError

url = "https://segmentfault.com"
data = get_data(url)  # 获取数据
data # 查看数据
# Out:
# '\n<!DOCTYPE HTML><html lang="zh-CN"><head><meta charset="UTF-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge, chrome=1"/><meta name="renderer" content="webkit"/><meta property="qc:admins" content="15317273575564615446375"/><meta property="og:image" content="https://static.segmentfault.com/v-5c8b4d77/global/img/touch-icon.png"/><meta name="viewport"\n              content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no"/><meta name="alexaVerifyID" content="LkzCRJ7rPEUwt6fVey2vhxiw1vQ"/><meta name="apple-itunes-app" content="app-id=958101793, app-argument="><title>SegmentFault 思否</title><meta name="description" content="SegmentFault 思否 为开发者提供问答、学习与交流编程知识的平台，创造属于开发者的时代！"/><meta name="keywords" content="SegmentFault,思否,javascript,php,python,java,mysql,ios,android,vue.js,node.js,html,css,ruby,git,docker,前端"/><link rel="search" type="application/opensearchdescription+xml" href="/opensearch.xml" title="SegmentFault"/><link rel="shortcut icon" href="https://static.segmentfault.com/v-5c8b4d77/global/img/favicon.ico"/><link rel="apple-touch-icon" href="https://static.segmentfault.com/v-5c8b4d77/global/img/touch-icon.png"><meta name="msapplication-TileColor" content="#009a61"/><meta name="msapplication-square150x150logo" content="https://static.segmentfault.com/v-5c8b4d77/global/img/touch-icon.png"/><meta name="baidu_union_verify" content="bcf7fd80dca60d53d46d5b46e1b990ca"><link rel="alternate" type="application/atom+xml" title="SegmentFault 最新问题" href="/feeds/questions"><link rel="alternate" type="application/atom+xml" title="SegmentFault 最新文章" href="/feeds/blogs"><link rel="stylesheet" href="https://static.segmentfault.com/v-5c8b4d77/global/css/global.css"/><link rel="stylesheet" href="https://static.segmentfault.com/v-5c8b4d77/index/css/index.css"/><link rel="stylesheet" href="https://static.segmentfault.com/v-5c8b4d77/global/css/responsive.css"/><script type=\'text/javascript\' src=\'https://sponsor.segmentfault.com/spcjs.php?id=1&block=1&repu=0\'></script><script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script><script>\n        (adsbygoogle = window.adsbygoogle || []).push({\n            google_ad_client: "ca-pub-6330872677300335",\n            enable_page_level_ads: true\n        });\n    </script></head><body data-mod="index"\n    class="index-index "><!--[if lt IE 9]><div class="alert alert-danger topframe" role="alert">你的浏览器实在<strong>太太太太太太旧了</strong>，放学别走，升级完浏览器再说 <a target="_blank" class="alert-link" href="http://browsehappy.com">立即升级</a></div><![endif]--><img id="icon4weChat" style="height: 0;width: 0;" data-src="https://static.segmentfault.com/v-5c8b4d77/global/img/touch-icon-512.png"><div id="gridMapHoverBox" style="position:absolute; border: 1px solid #009a61; z-index:99; font-size: 10px; background:#fff"></div><div class="global-nav sf-header sf-header--index"><div class="bottom-nav visible-xs visible-sm "><div class="opts"><a class="opts-group active" href="/"><i class="fa fa-home" aria-hidden="true"></i><span>首页</span></a><a class="opts-group " href="/questions"><i class="fa fa-comments" aria-hidden="true"></i><span>问答</span></a><a class="opts-group " href="/blogs"><i class="fa fa-pencil-square" aria-hidden="true"></i><span>专栏</span></a><a class="opts-group " href="/lives"><i class="fa fa-play-circle" aria-hidden="true"></i><span>讲堂</span></a><div class="opts-group"><div class="btn-group dropup"><i class="fa fa-bars dropdown hoverDropdown" data-toggle="dropdown" aria-hidden="true"><span>更多</span></i><ul class="dropdown-menu"><li><a href="/jobs">职位</a></li><li><a href="/events">活动</a></li><li><a href="/tags">标签</a></li><li><a href="/badges">徽章</a></li></ul></div></div></div></div><nav class="container nav"><div class="visible-xs visible-sm header-response"><a href="/search" style="display:block"><i class="fa fa-search" aria-hidden="true"></i></a><div class="sf-header__logo sf-header__logo--response"><h1><a href="/" style="height:24px; background-size: auto 24 ...

# %% [markdown]
# ### scrapy提取数据

# %%
from scrapy import Selector
from urllib import parse  # 用于url合并的工具

# %%
se = Selector(text=data)

# %%
items = se.css(".news__item-info.clearfix")
for item in items:
    title = item.xpath(".//h4/text()").extract_first()  # 获取文章标题
    content = item.css(".article-excerpt::text").extract_first().strip()  # 获取文章描述
    content_url = item.xpath("./a/@href").extract_first()  # 获取文章url
    print(title)
    print(content)
    print(parse.urljoin(url,content_url))  # 合并url，形成完整的url
    print()
# Out:
# 基于socket.io快速实现一个实时通讯应用
# 随着web技术的发展，使用场景和需求也越来越复杂，客户端不再满足于简单的请求得到状态的需求。实时通讯越来越多应用于各个领域。
# https://segmentfault.com/a/1190000018944634
#
# 【译】如何在 JavaScript 中使用对象的方法
# JavaScript 中，对象是 键/值 对的集合。值可以包含属性和方法，并且可以包含所有其他 JavaScript 数据类型，例如字符串，数字和布尔值。
# https://segmentfault.com/a/1190000018941250
#
# 45个值得收藏的 CSS 形状
# CSS能够生成各种形状。正方形和矩形很容易，因为它们是 web 的自然形状。添加宽度和高度，就得到了所需的精确大小的矩形。添加边框半径，你就可以把这个形状变成圆形，足够多的边框半径，你就可以把这些矩形变成...
# https://segmentfault.com/a/1190000018922732
#
# CQRS & Event Sourcing — 解决检索应用程序状态问题的一剂良方
# 现在，每个开发人员都很熟悉MVC标准体系结构设计模式。大多数的应用程序都是基于这种体系结构进行创建的。它允许我们创建可扩展的大型企业应用程序，但近期我们还听到了另外的一些有关于CQRS/ES的相关信息。这些...
# https://segmentfault.com/a/1190000018933462
#
# 服务端预渲染之Nuxt - （爬坑篇）
# Nuxt是解决SEO的比较常用的解决方案，随着Nuxt也有很多坑，每当突破一个小技术点的时候，都有很大的成就感，在这段时间里着实让我痛并快乐着。在这里根据个人学习情况，所踩过的坑做了一个汇总和总结。
# https://segmentfault.com/a/1190000018930829
#
# 一文掌握PHP Xdebug 本地与远程调试
# 我是在~/Downloads/xdebug/ 目录下放了一个简单的PHP文件test.php来测试，在这个目录下用php -S 127.0.0.1:7790起了个http服务，可参考进行下述配置。
# https://segmentfault.com/a/1190000018930597
#
# Zookeeper学习系列【一】 教会你Zookeeper的一些基础概念
# 最近加入了部门的技术兴趣小组，被分配了Zookeeper的研究任务。在研究过程当中，发现Zookeeper由于其开源的特性和其卓越的性能特点，在业界使用广泛，有很多的应用场景，而这些不同的应用场景实际上底层的原理都...
# https://segmentfault.com/a/1190000018927058
#
# 十五个常用的 Laravel 集合（Collection）
# Laravel Eloquent 通常返回一个集合作为结果，集合包含很多有用的、功能强大的方法。你可以很方便的对集合进行过滤、修改等操作。本次教程就一起来看一看集合的常用方法及功能。集合并不仅限于 eloquent ，也可以...
# https://segmentfault.com/a/1190000018924969
#
# 开发跨平台app推荐React Native还是flutter？
# 嗯。。。这个问题十分不好回答啊(捋下鱼须)。闲鱼作为flutter领域的先驱者，以及fish_redux、flutter_boost等当红flutter库的作者，当然是欢迎广大的开发者多多使用flutter相关技术栈 逃~:)。咳咳，不过呢，我们...
# https://segmentfault.com/a/1190000018920765
#
# 让前端监控数据采集更高效
# 随着业务的快速发展，我们对生产环境下的问题感知能力越来越关注。作为距离用户最近的一层，前端的表现是否可靠、稳定、好用，很大程度上决定着用户对整个产品的体验和感受。因此，对于前端的监控不容忽视。
# https://segmentfault.com/a/1190000018918875
#
# React diff原理探究以及应用实践
# React通过引入Virtual DOM的概念，极大地避免无效的Dom操作，已使我们的页面的构建效率提到了极大的提升。但是如何高效地通过对比新旧Virtual DOM来找出真正的Dom变化之处同样也决定着页面的性能，React用其特殊...
# https://segmentfault.com/a/1190000018914249
#
# 企业该如何提升自身技术品牌影响力？看看腾讯、美团、有赞是怎么做的
# 对于技术驱动型就企业来说，“保持技术持续领先”一直是企业发展战略的重中之重。但技术型企业往往低调务实，“如何塑造和传播企业的技术品牌”成为了一个重要的课题。企业申请软件著作权、专利技术、国家高新技术企...
# https://segmentfault.com/a/1190000018914067
#
# 思否讲堂新版上线，TypeScript完全解读26课时完更，这些好课值得关注！
# 俗话说“一年之计在于春”，金三银四不仅是跳槽的高峰期，也是学习充电的好时候。SegmentFault赶在春天上线了思否讲堂的新版本（点击这里即刻体验）！
# https://segmentfault.com/a/1190000018913739
#
# [PHP 安全] pcc —— PHP 安全配置检测工具
# 在 PHP 安全测试中最单调乏味的任务之一就是检查不安全的 PHP 配置项。作为一名 PHP 安全海报的继承者，我们创建了一个脚本用来帮助系统管理员如同安全专家一样尽可能快速且全面地评估 php.ini 和相关主题的状态...
# https://segmentfault.com/a/1190000018912225
#
# 开源|ns4_frame分布式服务框架开发指南
# 导语：宜信于2019年3月29日正式开源nextsystem4（以下简称“NS4”）系列模块。此次开源的NS4系列模块是围绕当前支付系统笨重、代码耦合度高、维护成本高而产生的分布式业务系统解决方案。NS4系列框架允许创建复杂的...
# https://segmentfault.com/a/1190000018911317
#
# 从用户成为“股东” —— 在 Apache 基金会的 2600 天
# 3月27日，腾讯云大数据及人工智能产品研发的专家研究员堵俊平受邀成为 Apache 软件基金会Member（Apache Softeware Foundation Member，以下简称 ASF Member），一封名为 “邀请成为 ASF Member” 的电子邮件正式为...
# https://segmentfault.com/a/1190000018906979
#
# 【译】TypeScript中的React高阶组件
# 高阶组件（HOCs）在React中是组件复用的一个强大工具。但是，经常有开发者在结合TypeScript使用中抱怨道很难去为其设置types。
# https://segmentfault.com/a/1190000018906665
#
# 数据可视化之下发图实践
# 随着互联网的快速发展，数据维度越来越广，呈现形式也越发丰富，具有多维度数据特点的相关业务实践都能通过可视化图表来展示，比如个推的下发图，从时间和区域两个维度，可以即时、直观地展现个推数据下发的过程。
# https://segmentfault.com/a/1190000018906329
#
# 11个教程中不常被提及的JavaScript小技巧
# 这次我们主要来分享11个在日常教程中不常被提及的JavaScript小技巧，他们往往在我们的日常工作中经常出现，但是我们又很容易忽略。
# https://segmentfault.com/a/1190000018897633
#
# 码上用它开始Flutter混合开发——FlutterBoost
# 具有一定规模的App通常有一套成熟通用的基础库，尤其是阿里系App，一般需要依赖很多体系内的基础库。那么使用Flutter重新从头开发App的成本和风险都较高。所以在Native App进行渐进式迁移是Flutter技术在现有Nati...
# https://segmentfault.com/a/1190000018896202
#
# JavaScript中的原型与原型链
# 前言 作为前端高频面试题之一，相信很多小伙伴都有遇到过这个问题。那么你是否清楚完整的了解它呢？ 国际惯例，让我们先抛出问题： 什么是原型、原型链 它们有什么特点 它们能做什么 怎么确定它们的关系 或许你已...
# https://segmentfault.com/a/1190000018895543
#
# 【React深入】深入分析虚拟DOM的渲染原理和特性
# React的虚拟DOM和Diff算法是React的非常重要的核心特性，这部分源码也非常复杂，理解这部分知识的原理对更深入的掌握React是非常必要的。
# https://segmentfault.com/a/1190000018891454
#
# JavaScript 是如何工作的：JavaScript 的共享传递和按值传递
# 这是专门探索 JavaScript 及其所构建的组件的系列文章的第 22 篇。 如果你错过了前面的章节，可以在这里找到它们： JavaScript 是如何工作的：引擎，运行时和调用堆栈的概述！ JavaScript 是如何工作的：深入V8引...
# https://segmentfault.com/a/1190000018862368
#
# Swoole协程之旅-前篇
# Swoole协程经历了几个里程碑，我们需要在前进的道路上不断总结与回顾自己的发展历程，正所谓温故而知新，本系列文章将分为协程之旅前、中、后三篇。
# https://segmentfault.com/a/1190000018889185
#
# 现代IM系统中的消息系统架构 - 架构篇
# IM全称是『Instant Messaging』，中文名是即时通讯。在这个高度信息化的移动互联网时代，生活中IM类产品已经成为必备品，比较有名的如钉钉、微信、QQ等以IM为核心功能的产品。当然目前微信已经成长为一个生态型产...
# https://segmentfault.com/a/1190000018887327
#
# Redis 概念以及底层数据结构
# REmote DIctionary Server(Redis) 是一个由SalvatoreSanfilippo写的key-value存储系统。
# https://segmentfault.com/a/1190000018887256
#
# 开源|宜信开源专注业务逻辑的轻量级服务框架nextsystem4
# 此次开源的NS4系列模块是围绕当前支付系统笨重、代码耦合度高、维护成本高而产生的分布式业务系统解决方案。NS4系列框架允许创建复杂的流程/业务流，对于业务服务节点的实现可串联，可分布式。其精简、轻量，实现...
# https://segmentfault.com/a/1190000018883786
#
# React Native 常用的 15 个库
# 本篇 React native 库列表不是从网上随便找的， 这些是我在我的应用中亲自使用的库。 这些库功能可能跟其它库也有，但经过大量研究并在我的程序中尝试后，我选择了这些库。
# https://segmentfault.com/a/1190000018882944
#
# 腾讯重磅开源分布式NoSQL存储系统DCache
# 当你在电商平台秒杀商品或者在社交网络刷热门话题的时候，可以很明显感受到当前网络数据流量的恐怖，几十万商品刚开抢，一秒都不到就售罄；哪个大明星出轨的消息一出现，瞬间阅读与转发次数可以达到上亿。作为终...
# https://segmentfault.com/a/1190000018873886
#
# 2019前端工程师自检清单与思考
# 对于JavaScript，掌握其语法和特性是最基本的，但是这些只是应用能力，最终仍旧考量仍然是计算机体系的理论知识，所以数据结构，算法，软件工程，设计模式等基础知识对前端工程师同样重要，这些知识的理解程度，...
# https://segmentfault.com/a/1190000018873042

# %% [markdown]
# ### requests 获取推荐数据

# %%
a_url = "https://segmentfault.com/api/timelines/recommend"
page = 2
_ = "100f22ae30d035f334a31542ea388b4d"
params = {"page": page, "_": _}
headers = {
    "cookie": "PHPSESSID=web2~mi7pa9ed552n7vfmpcslr5i6va",  # 必带
    "referer": "https://segmentfault.com/",  # 必带
}

# %%
response = requests.get(a_url, params=params, headers=headers)
response.json()
# Out:
# {'status': 0,
#  'data': [{'id': '1190000018895543',
#    'url': '/a/1190000018895543',
#    'createdDate': '4月17日',
#    'votes': '51',
#    'viewsWord': 865,
#    'title': 'JavaScript中的原型与原型链',
#    'status': '2',
#    'excerpt': '前言 作为前端高频面试题之一，相信很多小伙伴都有遇到过这个问题。那么你是否清楚完整的了解它呢？ 国际惯例，让我们先抛出问题： 什么是原型、原型链 它们有什么特点 它们能做什么 怎么确定它们的关系 或许你已...',
#    'imageUrl': 'https://segmentfault.com/img/remote/1460000018894221',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000018516861',
#    'user': {'name': '游荡de蝌蚪',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/960/548/960548768-5c8b20f912b75_medium48',
#     'url': '/u/youdangde_5c8b208a23f95',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '前端爬坑', 'url': '/blog/ltadpole'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018891454',
#    'url': '/a/1190000018891454',
#    'createdDate': '4月17日',
#    'votes': '40',
#    'viewsWord': 851,
#    'title': '【React深入】深入分析虚拟DOM的渲染原理和特性',
#    'status': '2',
#    'excerpt': 'React的虚拟DOM和Diff算法是React的非常重要的核心特性，这部分源码也非常复杂，理解这部分知识的原理对更深入的掌握React是非常必要的。',
#    'imageUrl': 'https://segmentfault.com/img/remote/1460000018891457',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000013084144',
#    'user': {'name': 'ConardLi',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/112/194/1121942874-5bb3745dd5586_medium48',
#     'url': '/u/conardli',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '公众号code秘密花园', 'url': '/blog/conardli'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018862368',
#    'url': '/a/1190000018862368',
#    'createdDate': '4月17日',
#    'votes': '57',
#    'viewsWord': '1.7k',
#    'title': 'JavaScript 是如何工作的：JavaScript 的共享传递和按值传递',
#    'status': '2',
#    'excerpt': '这是专门探索 JavaScript 及其所构建的组件的系列文章的第 22 篇。 如果你错过了前面的章节，可以在这里找到它们： JavaScript 是如何工作的：引擎，运行时和调用堆栈的概述！ JavaScript 是如何工作的：深入V8引...',
#    'imageUrl': 'https://segmentfault.com/img/bVbriRT?w=1171&amp;h=523',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000007460810',
#    'user': {'name': '前端小智',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/392/949/3929497632-5c75d206ad1a5_medium48',
#     'url': '/u/minnanitkong',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '终身学习者', 'url': '/blog/zsxuexi'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018889185',
#    'url': '/a/1190000018889185',
#    'createdDate': '4月16日',
#    'votes': '14',
#    'viewsWord': 757,
#    'title': 'Swoole协程之旅-前篇',
#    'status': '2',
#    'excerpt': '\u2002\u2002Swoole协程经历了几个里程碑，我们需要在前进的道路上不断总结与回顾自己的发展历程，正所谓温故而知新，本系列文章将分为协程之旅前、中、后三篇。',
#    'imageUrl': None,
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000018164905',
#    'user': {'name': '石光启',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/265/422/2654220692-5c66644b1a021_medium48',
#     'url': '/u/shiguangqi',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': 'Swoole', 'url': '/blog/swoole'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018887327',
#    'url': '/a/1190000018887327',
#    'createdDate': '4月16日',
#    'votes': '20',
#    'viewsWord': 678,
#    'title': '现代IM系统中的消息系统架构 - 架构篇',
#    'status': '2',
#    'excerpt': 'IM全称是『Instant Messaging』，中文名是即时通讯。在这个高度信息化的移动互联网时代，生活中IM类产品已经成为必备品，比较有名的如钉钉、微信、QQ等以IM为核心功能的产品。当然目前微信已经成长为一个生态型产...',
#    'imageUrl': 'https://segmentfault.com/img/remote/1460000018887330',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000013722374',
#    'user': {'name': '阿里云云栖社区',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/339/149/3391496084-5cada86ad8c5f_medium48',
#     'url': '/u/yunqishequ_5aa899aad5395',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '阿里云栖社区', 'url': '/blog/yunqichengxuyuan'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018887256',
#    'url': '/a/1190000018887256',
#    'createdDate': '4月16日',
#    'votes': '21',
#    'viewsWord': 753,
#    'title': 'Redis 概念以及底层数据结构',
#    'status': '2',
#    'excerpt': 'REmote DIctionary Server(Redis) 是一个由SalvatoreSanfilippo写的key-value存储系统。',
#    'imageUrl': 'https://segmentfault.com/img/remote/1460000018887259',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000000622954',
#    'user': {'name': 'Worktile',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/428/463/4284638070-5c25ec7b8a2b8_medium48',
#     'url': '/u/worktile',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': 'Worktile', 'url': '/blog/worktile'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018883786',
#    'url': '/a/1190000018883786',
#    'createdDate': '4月16日',
#    'votes': '1',
#    'viewsWord': 429,
#    'title': '开源|宜信开源专注业务逻辑的轻量级服务框架nextsystem4',
#    'status': '2',
#    'excerpt': '此次开源的NS4系列模块是围绕当前支付系统笨重、代码耦合度高、维护成本高而产生的分布式业务系统解决方案。NS4系列框架允许创建复杂的流程/业务流，对于业务服务节点的实现可串联，可分布式。其精简、轻量，实现...',
#    'imageUrl': 'https://segmentfault.com/img/remote/1460000018883789',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000016816174',
#    'user': {'name': '宜信技术学院',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/253/247/2532479025-5bd2ca55089f0_medium48',
#     'url': '/u/gaoleihan',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '宜信技术学院', 'url': '/blog/creditease-tech'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018882944',
#    'url': '/a/1190000018882944',
#    'createdDate': '4月16日',
#    'votes': '46',
#    'viewsWord': 764,
#    'title': 'React Native 常用的 15 个库',
#    'status': '2',
#    'excerpt': '本篇 React native 库列表不是从网上随便找的， 这些是我在我的应用中亲自使用的库。 这些库功能可能跟其它库也有，但经过大量研究并在我的程序中尝试后，我选择了这些库。',
#    'imageUrl': 'https://segmentfault.com/img/bVbrnkn?w=306&amp;h=260',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000007460810',
#    'user': {'name': '前端小智',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/392/949/3929497632-5c75d206ad1a5_medium48',
#     'url': '/u/minnanitkong',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '终身学习者', 'url': '/blog/zsxuexi'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018873886',
#    'url': '/a/1190000018873886',
#    'createdDate': '4月15日',
#    'votes': '8',
#    'viewsWord': '1.1k',
#    'title': '腾讯重磅开源分布式NoSQL存储系统DCache',
#    'status': '2',
#    'excerpt': '当你在电商平台秒杀商品或者在社交网络刷热门话题的时候，可以很明显感受到当前网络数据流量的恐怖，几十万商品刚开抢，一秒都不到就售罄；哪个大明星出轨的消息一出现，瞬间阅读与转发次数可以达到上亿。作为终...',
#    'imageUrl': 'https://segmentfault.com/img/bVbrl5B?w=1380&amp;h=703',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000009179448',
#    'user': {'name': '腾讯开源',
#     'avatarUrl': 'https://cdn.segmentfault.com/v-5cc2cd8e/global/img/user-48.png',
#     'url': '/u/tengxunkaiyuan_58fdcd0c099d6',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '腾讯开源', 'url': '/blog/tencentopen01'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018873042',
#    'url': '/a/1190000018873042',
#    'createdDate': '4月15日',
#    'votes': '260',
#    'viewsWord': '3.6k',
#    'title': '2019前端工程师自检清单与思考',
#    'status': '2',
#    'excerpt': '对于JavaScript，掌握其语法和特性是最基本的，但是这些只是应用能力，最终仍旧考量仍然是计算机体系的理论知识，所以数据结构，算法，软件工程，设计模式等基础知识对前端工程师同样重要，这些知识的理解程度，...',
#    'imageUrl': 'https://segmentfault.com/img/bVbrlJk?w=1250&amp;h=1505',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000007721491',
#    'user': {'name': 'SuperX',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/135/740/1357404756-5c7be3eb8b40d_medium48',
#     'url': '/u/qzuser_584786517d31a',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '考拉阅读前端团队', 'url': '/blog/koalafe'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018870862',
#    'url': '/a/1190000018870862',
#    'createdDate': '4月15日',
#    'votes': '20',
#    'viewsWord': '1.5k',
#    'title': '【译】使用TypeScript两年后-值得吗？',
#    'status': '2',
#    'excerpt': '这是我的第一篇翻译文章，想看这篇文章的时候，发现没有中文翻译版，无奈去读了英文版，读完发现可以试试翻译出来。',
#    'imageUrl': 'https://segmentfault.com/img/remote/1460000018870865',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000004538816',
#    'user': {'name': '方旭',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/263/838/2638387867-56da6b96a8178_medium48',
#     'url': '/u/fangxu',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '陈工移山', 'url': '/blog/qiqihaobenben'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018870032',
#    'url': '/a/1190000018870032',
#    'createdDate': '4月15日',
#    'votes': '6',
#    'viewsWord': 426,
#    'title': 'Node.js 应用故障排查手册 —— 类死循环导致进程阻塞',
#    'status': '2',
#    'excerpt': '在实践篇一中我们看到了两个表象都是和 CPU 相关的生产问题，它们基本也是我们在线上可能遇到的这一类问题的典型案例，而实际上这两个案例也存在一个共同点：我们可以通过\xa0Node.js 性能平台\xa0导出进程对应的 CPU P...',
#    'imageUrl': 'https://segmentfault.com/img/remote/1460000018870035',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000013722374',
#    'user': {'name': '阿里云云栖社区',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/339/149/3391496084-5cada86ad8c5f_medium48',
#     'url': '/u/yunqishequ_5aa899aad5395',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '阿里云栖社区', 'url': '/blog/yunqichengxuyuan'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018869555',
#    'url': '/a/1190000018869555',
#    'createdDate': '4月15日',
#    'votes': '220',
#    'viewsWord': '3k',
#    'title': '【周刊-2】三年大厂面试官-前端面试题（偏难）',
#    'status': '2',
#    'excerpt': '在大厂工作了6年，当了3年的前端面试官，把大厂常问的面试题与答案汇总在我的Github中。希望对大家有所帮助，助力大家进入自己理想的企业。',
#    'imageUrl': None,
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000012956098',
#    'user': {'name': '第一名的小蝌蚪',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/207/007/207007958-5c24c2519a876_medium48',
#     'url': '/u/diyimingdexiao',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '第一名的小蝌蚪的个人文章', 'url': '/u/diyimingdexiao/articles'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018869539',
#    'url': '/a/1190000018869539',
#    'createdDate': '4月15日',
#    'votes': '21',
#    'viewsWord': 667,
#    'title': 'Python 数据科学基础知识 ',
#    'status': '2',
#    'excerpt': '在 Python 中有许多数据类型。最常见的是float（浮点型），int（整型），str（字符串），bool（布尔），list 和 dict（字典）。',
#    'imageUrl': None,
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000000465839',
#    'user': {'name': '疯狂的技术宅',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/123/843/1238436638-597c1a465bbd2_medium48',
#     'url': '/u/evilboy',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '疯狂的技术宅', 'url': '/blog/creazy'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018868126',
#    'url': '/a/1190000018868126',
#    'createdDate': '4月15日',
#    'votes': '5',
#    'viewsWord': 378,
#    'title': '个推基于 Apache Pulsar 的优先级队列方案',
#    'status': '2',
#    'excerpt': '在个推的推送场景中，消息队列在整个系统中占有非常重要的位置。当 APP 有推送需求的时候, 会向个推发送一条推送命令，接到推送需求后，我们会把APP要求推送消息的用户放入下发队列中，进行消息下发；当同时有多...',
#    'imageUrl': 'https://segmentfault.com/img/remote/1460000018868129',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000000513473',
#    'user': {'name': '个推',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/347/816/3478161986-5c3de53865ec4_medium48',
#     'url': '/u/getui',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '个推推送 GeTui', 'url': '/blog/getui'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018867825',
#    'url': '/a/1190000018867825',
#    'createdDate': '4月15日',
#    'votes': '11',
#    'viewsWord': '1.2k',
#    'title': '有赞百亿级日志系统架构设计',
#    'status': '2',
#    'excerpt': '日志是记录系统中各种问题信息的关键，也是一种常见的海量数据。日志平台为集团所有业务系统提供日志采集、消费、分析、存储、索引和查询的一站式日志服务。主要为了解决日志分散不方便查看、日志搜索操作复杂且...',
#    'imageUrl': 'https://segmentfault.com/img/remote/1460000018867828',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000013534334',
#    'user': {'name': '有赞技术',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/194/785/1947851634-5a9e9ba1141d0_medium48',
#     'url': '/u/youzantech',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '有赞技术', 'url': '/blog/youzantech'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018854431',
#    'url': '/a/1190000018854431',
#    'createdDate': '4月15日',
#    'votes': '101',
#    'viewsWord': '1.7k',
#    'title': 'JavaScript 是如何工作的：JavaScript 的内存模型',
#    'status': '2',
#    'excerpt': '这是专门探索 JavaScript 及其所构建的组件的系列文章的第 21 篇。 如果你错过了前面的章节，可以在这里找到它们： JavaScript 是如何工作的：引擎，运行时和调用堆栈的概述！ JavaScript 是如何工作的：深入V8引...',
#    'imageUrl': 'https://segmentfault.com/img/bVbrfX3?w=720&amp;h=230',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000007460810',
#    'user': {'name': '前端小智',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/392/949/3929497632-5c75d206ad1a5_medium48',
#     'url': '/u/minnanitkong',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '终身学习者', 'url': '/blog/zsxuexi'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018857480',
#    'url': '/a/1190000018857480',
#    'createdDate': '4月13日',
#    'votes': '134',
#    'viewsWord': '2.3k',
#    'title': 'HTTP基本知识、跨域和调试技巧',
#    'status': '2',
#    'excerpt': '其实很多面试问HTTP的3次握手，4次挥手，我觉得价值不大，可以帮助你理解HTTP的原理，死背硬记的对于你开发没有作用，而是去理解它就行。前端只关心URL、headers和data，接下来也围绕着它们展开。 了解HTTP请求可...',
#    'imageUrl': 'https://segmentfault.com/img/bVbrgQu?w=397&amp;h=134',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000008179631',
#    'user': {'name': 'SmartCoder',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/212/854/212854021-5baee4a4687cf_medium48',
#     'url': '/u/qianduanlangzi_5881b7a7d77f0',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': 'SmartCoder的个人文章',
#     'url': '/u/qianduanlangzi_5881b7a7d77f0/articles'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018849878',
#    'url': '/a/1190000018849878',
#    'createdDate': '4月12日',
#    'votes': '63',
#    'viewsWord': '1.3k',
#    'title': 'Python 编程速成',
#    'status': '2',
#    'excerpt': 'Python是一种非常流行的脚本语言，而且功能非常强大，几乎可以做任何事情，比如爬虫、网络工具、科学计算、树莓派、Web开发、游戏等各方面都可以派上用场。同时无论在哪种平台上，都可以用 Python 进行系统编程。',
#    'imageUrl': 'https://segmentfault.com/img/bVRyYe?w=430&amp;h=430',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000000465839',
#    'user': {'name': '疯狂的技术宅',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/123/843/1238436638-597c1a465bbd2_medium48',
#     'url': '/u/evilboy',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '疯狂的技术宅', 'url': '/blog/creazy'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018842701',
#    'url': '/a/1190000018842701',
#    'createdDate': '4月12日',
#    'votes': '113',
#    'viewsWord': '2.6k',
#    'title': '如何画出一张合格的技术架构图？',
#    'status': '2',
#    'excerpt': '阿里妹导读：技术传播的价值，不仅仅体现在通过商业化产品和开源项目来缩短我们构建应用的路径，加速业务的上线速率，也体现在优秀工程师在工作效率提升、产品性能优化和用户体验改善等经验方面的分享，以提高我...',
#    'imageUrl': 'https://segmentfault.com/img/remote/1460000018842704',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000013722374',
#    'user': {'name': '阿里云云栖社区',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/339/149/3391496084-5cada86ad8c5f_medium48',
#     'url': '/u/yunqishequ_5aa899aad5395',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '阿里云栖社区', 'url': '/blog/yunqichengxuyuan'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018837535',
#    'url': '/a/1190000018837535',
#    'createdDate': '4月11日',
#    'votes': '7',
#    'viewsWord': '1.2k',
#    'title': '揭秘京东区块链开源项目——JD Chain',
#    'status': '2',
#    'excerpt': '近日，京东区块链底层引擎JD Chain正式对外开源并同步上线开源社区，旨在为企业级用户和开发者提供开源服务，帮助他们提高研发效率，加速技术创新。3月30日，国家互联网信息办公室公布了第一批区块链信息服务名称...',
#    'imageUrl': 'https://segmentfault.com/img/bVbrcEW',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000018471929',
#    'user': {'name': '京东云技术新知',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/182/117/1821178842-5c922d111841f_medium48',
#     'url': '/u/jdcdevloper',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '京东云技术新知', 'url': '/blog/jdcdevloper'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018828048',
#    'url': '/a/1190000018828048',
#    'createdDate': '4月11日',
#    'votes': '103',
#    'viewsWord': '2.2k',
#    'title': 'Web 性能优化：Preload,Prefetch的使用及在 Chrome 中的优先级',
#    'status': '2',
#    'excerpt': '这是 Web 性能优化的第 6 篇，上一篇在下面看点击查看： Web 性能优化：使用 Webpack 分离数据的正确方法 Web 性能优化：图片优化让网站大小减少 62% Web 性能优化：缓存 React 事件来提高性能 Web 性能优化：21...',
#    'imageUrl': 'https://segmentfault.com/img/bVbq62t?w=2304&amp;h=1426',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000007460810',
#    'user': {'name': '前端小智',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/392/949/3929497632-5c75d206ad1a5_medium48',
#     'url': '/u/minnanitkong',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '终身学习者', 'url': '/blog/zsxuexi'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018827395',
#    'url': '/a/1190000018827395',
#    'createdDate': '4月11日',
#    'votes': '98',
#    'viewsWord': '1.8k',
#    'title': '前端性能优化不完全手册    ',
#    'status': '2',
#    'excerpt': '3.浏览器发出读取文件(URL 中域名后面部分对应的文件)的HTTP 请求，该请求报文作为 TCP 三次握手的第三个报文的数据发送给服务器;',
#    'imageUrl': None,
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000018551718',
#    'user': {'name': 'Jerry谭金杰',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/216/918/2169181572-5c910e279bb58_medium48',
#     'url': '/u/jerrytanjinjie',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': 'Jerry谭金杰的个人文章', 'url': '/u/jerrytanjinjie/articles'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018811476',
#    'url': '/a/1190000018811476',
#    'createdDate': '4月10日',
#    'votes': '68',
#    'viewsWord': '1.4k',
#    'title': '【React深入】从Mixin到HOC再到Hook',
#    'status': '2',
#    'excerpt': '前端发展速度非常之快，页面和组件变得越来越复杂，如何更好的实现状态逻辑复用一直都是应用程序中重要的一部分，这直接关系着应用程序的质量以及维护的难易程度。',
#    'imageUrl': 'https://lsqimg-1257917459.cos-website.ap-beijing.myqcloud.com/blog/hook2.png',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000013084144',
#    'user': {'name': 'ConardLi',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/112/194/1121942874-5bb3745dd5586_medium48',
#     'url': '/u/conardli',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '公众号code秘密花园', 'url': '/blog/conardli'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018810837',
#    'url': '/a/1190000018810837',
#    'createdDate': '4月10日',
#    'votes': '134',
#    'viewsWord': '2.1k',
#    'title': '30 分钟快速入门 Docker 教程',
#    'status': '2',
#    'excerpt': '原文地址：梁桂钊的博客博客地址：[链接] 欢迎关注公众号：「服务端思维」。一群同频者，一起成长，一起精进，打破认知的局限性。',
#    'imageUrl': 'https://segmentfault.com/img/remote/1460000018810840',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000012835530',
#    'user': {'name': '梁桂钊',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/401/031/4010318965-5a61e349c3c80_medium48',
#     'url': '/u/lianggzone',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '服务端思维', 'url': '/blog/lianggzone'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018796317',
#    'url': '/a/1190000018796317',
#    'createdDate': '4月9日',
#    'votes': '129',
#    'viewsWord': '2.5k',
#    'title': '前端练级攻略(第二部分)',
#    'status': '2',
#    'excerpt': '在第二部分，我们将重点学习 JavaScript 作为一种独立的语言，如何向界面添加交互性，JavaScript 设计和架构模式，以及如何构建网络应用程序。',
#    'imageUrl': 'https://segmentfault.com/img/bVbqWTh?w=720&amp;h=311',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000007460810',
#    'user': {'name': '前端小智',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/392/949/3929497632-5c75d206ad1a5_medium48',
#     'url': '/u/minnanitkong',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '终身学习者', 'url': '/blog/zsxuexi'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018785911',
#    'url': '/a/1190000018785911',
#    'createdDate': '4月8日',
#    'votes': '240',
#    'viewsWord': '5.9k',
#    'title': '深入理解前端性能监控',
#    'status': '2',
#    'excerpt': '在同样的网络环境下，有两个同样能满足你的需求的网站，一个唰的一下就加载出来了，另一个白屏转圈转了半天内容才出来，如果让你选择，你会用哪一个？',
#    'imageUrl': 'https://segmentfault.com/img/bVbqZbf?w=1300&amp;h=400',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000018233587',
#    'user': {'name': 'TNFE',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/302/775/3027754140-5c6e608d3241a_medium48',
#     'url': '/u/tnfe',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '腾讯新闻前端团队', 'url': '/blog/tnfe'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018775065',
#    'url': '/a/1190000018775065',
#    'createdDate': '4月8日',
#    'votes': '177',
#    'viewsWord': '2.9k',
#    'title': '前端练级攻略(第一部分)',
#    'status': '2',
#    'excerpt': '我记得我刚开始学习前端开发的时候。我看到了很多文章及资料，被学习的资料压得喘不过气来，甚至不知道从哪里开始。',
#    'imageUrl': 'https://segmentfault.com/img/bVbqTCI?w=800&amp;h=600',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000007460810',
#    'user': {'name': '前端小智',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/392/949/3929497632-5c75d206ad1a5_medium48',
#     'url': '/u/minnanitkong',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': '终身学习者', 'url': '/blog/zsxuexi'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018777972',
#    'url': '/a/1190000018777972',
#    'createdDate': '4月6日',
#    'votes': '32',
#    'viewsWord': '1.5k',
#    'title': '【Go源码分析】Go scheduler 源码分析',
#    'status': '2',
#    'excerpt': '一个进程可以有多个线程，一般情况下固定2MB内存块来做栈，用来保存当前被调用/挂起的函数内部的变量，CPU在执行调度的时候切换的是线程，如果下一个线程也是当前进程的，就只有线程切换，“很快”就能完成；如果下...',
#    'imageUrl': None,
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000013109758',
#    'user': {'name': 'LNMPR源码研究',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/417/980/4179801286-5c1c59792988a_medium48',
#     'url': '/u/php7internal',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': 'LNMPR源码研究的个人文章', 'url': '/u/php7internal/articles'},
#    'currentHideSetting': 'none',
#    'type': 'article'},
#   {'id': '1190000018777955',
#    'url': '/a/1190000018777955',
#    'createdDate': '4月6日',
#    'votes': '26',
#    'viewsWord': 850,
#    'title': '服务端预渲染之Nuxt（介绍篇）',
#    'status': '2',
#    'excerpt': '现在前端开发一般都是前后端分离，mvvm和mvc的开发框架，如Angular、React和Vue等，虽然写框架能够使我们快速的完成开发，但是由于前后台分离，给项目SEO带来很大的不便，搜索引擎在检索的时候是在网页中爬取数据...',
#    'imageUrl': 'https://segmentfault.com/img/bVbqXan?w=443&amp;h=595',
#    'isBookmarked': False,
#    'isLiked': False,
#    'user_id': '1030000011768211',
#    'user': {'name': 'Aaron',
#     'avatarUrl': 'https://avatar-static.segmentfault.com/951/381/951381463-5a1277504fc35_medium48',
#     'url': '/u/aaron_59f5c5ee0c93f',
#     'isUserAuth': False,
#     'userAuthInfo': None},
#    'blog': {'name': 'Aaron的个人文章', 'url': '/u/aaron_59f5c5ee0c93f/articles'},
#    'currentHideSetting': 'none',
#    'type': 'article'}],
#  'message': ''}

# %%
response.json()["data"][0]["id"]
# Out:
# '1190000018895543'
